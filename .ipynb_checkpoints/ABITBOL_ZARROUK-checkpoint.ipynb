# %% [markdown]
# # PROJET  MOGPL <font color='red'> *'CHEMIN LE PLUS COURT'* </font>
#     ABITBOL Yossef, 3804139
#     ZARROUK Yael,  21107919

# %% [markdown]
# ## IMPORT

# %%
import copy
import numpy as np
import matplotlib.pyplot as plt
import time
import networkx as nx
import pickle
import random
import math
print("succes!")
# Out:
# succes!

# %% [markdown]
# # FONCTIONS POUR LA CREATION DU GRAPHE CLASSIQUE
# - soit on cree le graphe depuis un fichier txt, <br>
# - soit on le cree grace au terminal, on entre toutes les données nécessaires.

# %% [markdown]
# ## CREATION DU GRAPHE DEPUIS UN FICHIER TXT
# fonction : **ouvrir_fichier(chemin_fichier)** <br>
# Cette fonction nous renvoi : <br>
#         - un dictionnaire de sommets avec comme cle les sommet et pour valeur un index de (0 , nombre de sommets -1), <br>
#         - un ensemble d'arcs.
# <br> renvoi : G

# %%
def ouvrir_fichier(chemin_fichier):
    """str -> int * int * list[str] * list[list[str]]
    
    Cette fonction permet de soustraire du fichier texte son nombre de sommets, d'arcs ainsi que les sommets et les arcs
    """
    with open(chemin_fichier) as f : # on ouvre le fichier
        f = f.read().splitlines()  # on split en fonction des lignes 
        
         # on a le nombre de sommets 
        nombres_sommets = int(f[0])
        print(f"Le nombre de sommets est :  {nombres_sommets}")
        
        # on a le nombre d'arcs
        nombres_arcs = int(f[1])  
        print(f"Le nombres d'arc est : {nombres_arcs}")

        ###################  LES SOMMETS  
        sommets = []
        for i in range(2,nombres_sommets+2): #+2 car les premieres cases sont le nb de sommets et d'arcs 
            sommets.append(f[i])
#         print(f"Les sommets sont :{sommets}")
        sommets2 = {} 
        for i in range(len(sommets)): # on transforme les sommets en dico pour avoir des index lié a  chaque sommet
            sommets2[sommets[i]] = i 
        
        ###################  LES ARCS
        arcs2 = set() # pour eviter les doublons
        for i in range(2+nombres_sommets,len(f)):
#             print(f[i])
            g = f[i]
            g = g[1:-1].split(",") # on supprime les parentheses et on split en fonction des virgules
            arcs2.add((g[0],g[1],g[2],g[3])) # de la forme (u,v,t,lambda)
                
    return sommets2, arcs2

# %%
#---------------------------------------------TEST--------------------------------------------- 
f = 'instancetest2.txt' 
# f= 'instancetest.txt'
G = ouvrir_fichier(f) # ce G va nous etre utile pour la suite
print("---------------------------------------------------------------------------")
print(G)
# Out:
# Le nombre de sommets est :  5
# Le nombres d'arc est : 7
# ---------------------------------------------------------------------------
# ({'a': 0, 'b': 1, 'c': 2, 'f': 3, 'g': 4}, {('a', 'b', '2', '1'), ('a', 'c', '4', '1'), ('c', 'g', '7', '1'), ('a', 'b', '1', '1'), ('c', 'f', '6', '1'), ('b', 'f', '5', '1'), ('a', 'c', '2', '1')})

# %% [markdown]
# ## fichier different
# ouvrir_fichier2(fichier)

# %%
def ouvrir_fichier2(fichier):
    """str -> int * int * list[str] * list[list[str]]
    
    Cette fonction permet de soustraire du fichier texte son nombre de sommets, d'arcs ainsi que les sommets et les arcs
    """
    with open(fichier) as f : # on ouvre le fichier
        f = f.read().splitlines()  # on split en fonction des lignes 
        
         # on a le nombre de sommets 
        n= f[0].split("%")
        nombres_sommets = int(n[0])
        print(f"Le nombre de sommets est :  {nombres_sommets}")
        
        f = f[1 : ]
        # on a le nombre d'arcs
        n = f[0].split("%")
        nombres_arcs = int(n[0])  
        print(f"Le nombres d'arc est : {nombres_arcs}")
        
        f= f[1:]
        ###################  LES SOMMETS
        n = f[0:nombres_sommets]
        sommets = []
        for i in range(len(n)):
            tpt = n[i].split(" ")
            sommets.append(tpt[1])
#         print(f"Les sommets sont :{sommets}")
        sommets2 = {} 
        for i in range(len(sommets)): # on transforme les sommets en dico pour avoir des index lié a  chaque sommet
            sommets2[sommets[i]] = i 
        
        f= f[nombres_sommets:]
        ###################  LES ARCS
        arcs2 = set() # pour eviter les doublons
        for i in range(len(f)):
            tpt = f[i].split(" ")
            g = tpt[1]
            g = g[1:-1].split(",") # on supprime les parentheses et on split en fonction des virgules
            arcs2.add((g[0],g[1],g[2],g[3])) # de la forme (u,v,t,lambda)
                
    return sommets2, arcs2

# %%
#---------------------------------------------TEST--------------------------------------------- 
testcommentaire = ouvrir_fichier2('testcommentaire.txt')
print(testcommentaire)
# Out:
# Le nombre de sommets est :  5
# Le nombres d'arc est : 7
# ({'a': 0, 'b': 1, 'c': 2, 'f': 3, 'g': 4}, {('a', 'b', '2', '1'), ('a', 'c', '4', '1'), ('c', 'g', '7', '1'), ('a', 'b', '1', '1'), ('c', 'f', '6', '1'), ('b', 'f', '5', '1'), ('a', 'c', '2', '1')})

# %% [markdown]
# ## PREND EN PARAMETRE LES ARCS ET SOMMETS DEPUIS LE TERMINAL
# fonction : **creer_graphe_terminal()**

# %%
def creer_graphe_terminal():
    """
    Cette fonction permet de creer un graphe avec les données entres sur le terminal
    """
    #------------------------------ NOMBRE DE SOMMETS ------------------------------
    condition = True 
    while condition : 
        nombre_sommets = input(">>> veillez entrer le nombre de sommets :")
        # print(type(nombre_sommets))
        try:
            int(nombre_sommets)
            condition = False
        except ValueError:
            print("----- Veillez entrer un nombre -----")
            
    # ------------------------------ NOMBRE D'ARCS ------------------------------       
    condition = True 
    while condition : 
        nombre_arcs = input(">>> veillez entrer le nombre d'arcs :")
        # print(type(nombre_arcs))
        try:
            int(nombre_arcs)
            condition = False
        except ValueError:
            print("----- veillez entre un nombre -----")
    
    #------------------------------ LES SOMMETS ------------------------------
    condition = True 
    sommet =[]
    while condition : 
        cpt = input("veillez entrer le sommet (string) :")
        sommet.append(cpt)
        # print(type(sommets))
        if len(sommet) == int(nombre_sommets):
            condition = False
        elif (len(sommet) < int(nombre_sommets)):
            print(">>> sommet suivant ")  
            
    sommets2 = {} 
    for i in range(len(sommet)): # on transforme les sommets en dico pour avoir des index lié a  chaque sommet
        sommets2[sommet[i]] = i
    #------------------------------ LES ARCS ------------------------------
    condition1 = True 
    condition2 = True 
    arcs = set()
    while condition1 : 
        print("veillez entrer l'arc (u, v, temps, lambda)") 
        while condition2 : 
            u = input("--> commencons par u, le sommet de départ : ")
            # on test que u est bien un sommet 
            if  u in sommet: 
                condition2 = False 
            else :
                print("u n'est pas un sommet") 
                    
        while not(condition2) : 
            v = input("--> maintenant v , le sommet d'arrivé : ")
            # on test que u est bien un sommet
            if  v in sommet and v != u: 
                condition2 = True  
            else :
                print("v n'est pas un sommet valable ")         
         
        while condition2 : 
            temps = input("--> entrer le temps t de l'arc :")
            try:
                int(temps)
                condition2 = False
            except ValueError:
                print("----- Veillez entrer un nombre -----")
        while not(condition2) : 
            lambd = input("--> entrer lambda :")
            try:
                int(lambd)
                condition2 = True
            except ValueError:
                print("----- Veillez entrer un nombre -----")
                
        arcs.add((u,v,temps,lambd))
        # print(type(sommets))
        if len(arcs) == int(nombre_arcs):
            condition1 = False
        elif (len(arcs) < int(nombre_arcs)):
            print(">>> arc suivant ")  
    
    return sommets2 , arcs

# %%
G_terminal = creer_graphe_terminal()
print(G_terminal)
# Out:
# >>> veillez entrer le nombre de sommets : 2
# >>> veillez entrer le nombre d'arcs : 2
# veillez entrer le sommet (string) : a
# >>> sommet suivant
# veillez entrer le sommet (string) : b
# veillez entrer l'arc (u, v, temps, lambda)
# --> commencons par u, le sommet de départ :  a
# --> maintenant v , le sommet d'arrivé :  b
# --> entrer le temps t de l'arc : 3
# --> entrer lambda : 1
# >>> arc suivant
# veillez entrer l'arc (u, v, temps, lambda)
# --> commencons par u, le sommet de départ :  a
# --> maintenant v , le sommet d'arrivé :  b
# --> entrer le temps t de l'arc : 4
# --> entrer lambda : 1
# ({'a': 0, 'b': 1}, {('a', 'b', '3', '1'), ('a', 'b', '4', '1')})

# %%
# G = G_terminal

# %% [markdown]
# ## Transformation en graphe classique
# fonction : **graphe_classique(Graphe)** <br>
# On renvoi ici les sommets et aretes du nouveau graphe classique <br>
# retour : Gclassique

# %%
def graphe_classique(G):
    """
    Cette fonction permet de tranformer un multigraphe en graphe classique 
    """
    sommets , arcs = G
    sommet_classique = set()
    arcs_classique = set()
    
    for (u,v,time,lambd) in arcs:
        # Ajout des sommets
        sommet_classique.add((u,int(time))) #Vout
        sommet_classique.add((v,int(time)+int(lambd))) #Vin 
        # Ajout des aretes
        arcs_classique.add( ((u,int(time)),int(lambd),(v,int(time)+int(lambd)))) # Vout , lambda , Vin
        
    # ca va nous permettre de mettre les arcs a 0 entre les meme sommets 
    toRemove = sommet_classique.copy()
    while len(toRemove) != 0:
        u,t1 = toRemove.pop() # on prend un element de l'ensemble 
        # on cree une liste avec tous les elements qui ont le meme sommet 
        stock = []
        stock.append((u,t1))
        for v,t2 in toRemove :
            if u == v : 
                stock.append((v,t2)) # on met dans stock les meme elements de sommet u
        # on remet le sommet enleve dans l'ensemble 
        toRemove.add((u,t1))
        # on a du coup tout les elements dans la liste temporaire stock 
        stock = sorted(stock) # pour avoir que les arcs relie a ceux superieur directement 
        for i in range(len(stock)):
            toRemove.remove(stock[i])  # on enleve tous les sommets qu'on vient d'implementer
            if i < len(stock) - 1 :
                arcs_classique.add((stock[i],0,stock[i+1])) # on met l'arc a 0 

    liste1 = list(sommet_classique) # on transforme en dico
    sommetdic = {}
    for i in range(len(liste1)) :
        sommetdic[liste1[i]] = i

    return (sommetdic,arcs_classique)

# %%
#---------------------------------------------TEST--------------------------------------------- 
Gclassique = graphe_classique(G)
print(Gclassique)
# Out:
# ({('a', 4): 0, ('a', 1): 1, ('b', 3): 2, ('c', 3): 3, ('c', 5): 4, ('g', 8): 5, ('b', 2): 6, ('f', 7): 7, ('b', 5): 8, ('c', 7): 9, ('a', 2): 10, ('c', 6): 11, ('f', 6): 12}, {(('c', 7), 1, ('g', 8)), (('a', 2), 0, ('a', 4)), (('c', 3), 0, ('c', 5)), (('a', 2), 1, ('b', 3)), (('b', 5), 1, ('f', 6)), (('f', 6), 0, ('f', 7)), (('c', 6), 1, ('f', 7)), (('a', 4), 1, ('c', 5)), (('a', 2), 1, ('c', 3)), (('b', 3), 0, ('b', 5)), (('a', 1), 1, ('b', 2)), (('b', 2), 0, ('b', 3)), (('c', 5), 0, ('c', 6)), (('c', 6), 0, ('c', 7)), (('a', 1), 0, ('a', 2))})

# %% [markdown]
# # FONCTIONS UTILES POUR DIJKSTRA

# %% [markdown]
# ### Fonction pour trouver le sommet d'arrivé le plus élevé

# %%
def sommetMax(Gclassique, sommet_max , t_omega):
    """
    (dict{tuple(str,int) : int}, set((str,int),int,(str,int))) * str * int -> (str,int) 
    on cherche le sommet avec le temps le plus eleve 
    """
    sommet ,arcs = Gclassique 
    tpt = -math.inf 
    maximum = sommet_max
    for (s,t) in sommet :
        if s == sommet_max:
            if t > tpt and t<= t_omega:
                tpt = t
                maximum = s
    if tpt == -math.inf :
        return None 
    else:
        return (maximum, tpt)

# %%
#---------------------------------------------TEST--------------------------------------------- 
arrive = sommetMax(Gclassique,'c',math.inf)
print(arrive)
# Out:
# ('c', 7)

# %% [markdown]
# ### Fonction pour trouver le sommet de départ le moins élevé

# %%
def sommetMin(Gclassique, sommet_min , t_alpha):
    """
    (dict{tuple(str,int) : int}, set((str,int),int,(str,int))) * str * int -> (str,int) 
    on cherche le sommet avec le temps le moins eleve 
    """
    sommet ,arcs = Gclassique 
    tpt = math.inf
    minimum = sommet_min
    for (s,t) in sommet :
        if s == sommet_min:
            if t < tpt and t >= t_alpha:
                tpt = t
                maximum = s
    if tpt == math.inf :
        return None 
    else:
        return (minimum, tpt)

# %%
#---------------------------------------------TEST--------------------------------------------- 
depart = sommetMin(Gclassique,'a',-math.inf)
print(depart)
# Out:
# ('a', 1)

# %% [markdown]
# ### initialisation de dijkstra
# fonction : **initDijkstra(Gtype, init)** <br>
# renvoi : degre , predecesseur

# %%
def initDijkstra(G, sommet_init):
    """
    (dict{tuple(str,int) : int}, set((str,int),int,(str,int)))*(str,int) -> list[int]*list[]
    Cette fonction permet d'initialiser dijkstra en mettant le sommet 'de depart' a 0 et le reste a l'infini
    """
    sommets , arcs = G
    predecesseur = [None for i in range(len(sommets))]
    degres = [1000000 for i in range(len(sommets))]
    degres[sommets[sommet_init]] = 0
    return degres, predecesseur

# %%
#---------------------------------------------TEST--------------------------------------------- 
degre , pred = initDijkstra(Gclassique,depart)
print(degre)
print(pred)
# Out:
# [1000000, 0, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000, 1000000]
# [None, None, None, None, None, None, None, None, None, None, None, None, None]

# %%
def trouveMin(sommets,degre):
    """
    Cette fonction permet de trouver le minimum de degre minimum
    """
    minimum = math.inf
    sommet = None
    for s in sommets:
        if degre[sommets[s]] < minimum :
            minimum = degre[sommets[s]]
            sommet = s
    return sommet

# %%
#---------------------------------------------TEST--------------------------------------------- 
s , a = Gclassique
sommeet = trouveMin(s, degre)
print(sommeet)
# Out:
# ('a', 1)

# %% [markdown]
# ### maj dijkstra

# %% [markdown]
# # <font color='red'> Chemin d'arrivé au plus tot, Type I  </font>
# Pour résoudre le probléme du **chemin d'arrivé au plus tot, de type 1,** on va procéder de la maniere suivante.<br>
# Tout d'abord, on va transformer le multigraphe en un graphe classique grace aux fonctions précédentes et de ce nouveau graphe on va modifier la valeurs des arêtes.<br> Chaque arc de (u,t1) a (v,t2) de valeur x va etre **remplacé** par <font color='red' >la valeur de t2 - t1 </font>, sauf pour les arcs de (arrive,t1) a (arrive,t2) qui garde la valeur de 0. <br>
# Enfin, on applique dijkstra entre le min du depart et le max de l'arrivée

# %% [markdown]
# ## Graphe classique en graphe de type 1

# %%
def transformation1(Gclassique, arrivee):
    """
    Ici, on transforme le graphe classique pour l'adapter a notre chemin de type 1
    """
    sommets, arcs = Gclassique # on extrait les sommets et les arcs 
    arcs_modif = set()
    for ((u,t1),time,(v,t2)) in arcs : # pour chaque arc 
        if u == v and u == arrivee: # si c'est l'arc d'arrive 
            arcs_modif.add(((u,t1),time,(v,t2))) # on laisse sa valeur, c'est a dire 0 
        else :
            arcs_modif.add( ((u,t1),(t2-t1),(v,t2))) # on ajoute les arcs en modifiant leur valeur par t2-t1 
    return sommets, arcs_modif

# %%
#---------------------------------------------TEST--------------------------------------------- 
G1 = transformation1(Gclassique,'f')
print(G1)
# Out:
# ({('a', 4): 0, ('a', 1): 1, ('b', 3): 2, ('c', 3): 3, ('c', 5): 4, ('g', 8): 5, ('b', 2): 6, ('f', 7): 7, ('b', 5): 8, ('c', 7): 9, ('a', 2): 10, ('c', 6): 11, ('f', 6): 12}, {(('b', 2), 1, ('b', 3)), (('c', 7), 1, ('g', 8)), (('c', 5), 1, ('c', 6)), (('a', 2), 1, ('b', 3)), (('b', 5), 1, ('f', 6)), (('f', 6), 0, ('f', 7)), (('c', 6), 1, ('f', 7)), (('a', 4), 1, ('c', 5)), (('a', 2), 1, ('c', 3)), (('c', 6), 1, ('c', 7)), (('a', 1), 1, ('a', 2)), (('c', 3), 2, ('c', 5)), (('b', 3), 2, ('b', 5)), (('a', 1), 1, ('b', 2)), (('a', 2), 2, ('a', 4))})

# %% [markdown]
# ## DIJKSTRA type 1
# fonction : **dijkstra1(Gclassique, depart, arrivee, t_alpha, t_omega)** <br>

# %%
def dijkstra1(Gclassique, depart, arrivee, t_alpha, t_omega):
    """
    Cette fonction permet de faire l'algo de dijkstra pour le type I
    """
    G = transformation1(Gclassique,arrivee) #on transforme le graphe 
    arrivee = sommetMax(G,arrivee, t_omega) # le sommet max d'arrive 
    depart = sommetMin(G,depart, t_alpha) # le sommet min de depart 

    V,E = G
    
    Degres, Predecesseur = initDijkstra(G, depart) # on initialise les degres et predecesseur 
    
    DejaVu = set() #sommet visite 
    NonVisite = V.copy() # au depart aucun sommet visite 
    while len(NonVisite)!=0 and (trouveMin(NonVisite,Degres) != arrivee):
        # on cherche le successeur de degre min 
        s1,t1 = trouveMin(NonVisite,Degres)
        DejaVu.add(s1) # on ajoute le sommet visite
        NonVisite.pop((s1,t1)) # on le supprime des sommets non visite 
        for ((s,t),time,(s2,t2)) in E : # maj des dist
            if (s,t) == (s1,t1) : 
                # Si la distance du sommet de depart à s2 est plus grande 
                # que celle du sommet de depart à S1 plus celle de S1 à S2 
                if Degres[V[(s2,t2)]] > Degres[V[(s1,t1)]] + time : 
                    Degres[V[(s2,t2)]] = Degres[V[(s1,t1)]] + time #On prend ce nouveau chemin qui est plus court
                    Predecesseur[V[(s2,t2)]] = (s1,t1) #En notant par où on passe
    s = arrivee
    Sol = [s]
    while s != depart and s!=None :
        s = Predecesseur[V[s]]
        Sol = [s] + Sol
    if s == None:  
        return []
    return Sol

# %%
#---------------------------------------------TEST--------------------------------------------- 
print(dijkstra1(Gclassique,'a','f',-math.inf,math.inf))
#---------------------------------------------TEST--------------------------------------------- 
print(dijkstra1(Gclassique,'a','b',-math.inf,math.inf))
#---------------------------------------------TEST--------------------------------------------- 
print(dijkstra1(Gclassique,'b','g',-math.inf,math.inf))
# Out:
# [('a', 1), ('b', 2), ('b', 3), ('b', 5), ('f', 6), ('f', 7)]
# [('a', 1), ('b', 2), ('b', 3), ('b', 5)]
# []

# %% [markdown]
# # <font color='red'> Chemin de départ au plus tard, Type II  </font>
# Pour résoudre le probléme du **chemin de départ au plus tard, de type 2,** on va procéder de la maniere suivante.<br>
# Tout d'abord, on va transformer le multigraphe en un graphe classique grace aux fonctions précédentes et de ce nouveau graphe on va modifier la valeurs des arêtes.<br> Chaque arc de (depart,t1) a (depart,t2) de valeur x va etre **remplacé** par <font color='red' >la valeur de 0 </font> et les autres arcs par ta-td. <br>
# Enfin, on applique dijkstra entre le min du depart et le max de l'arrivée

# %% [markdown]
# ## Graphe classique en graphe de type 2

# %%
def transformation2(Gclassique,depart):
    """
    Cette fonction transforme le graphe classique  pour le type 2
    """
    sommets, arcs = Gclassique
    sommet_transforme, arcs_transforme = sommets,set()
    for ((u,tu),temps,(v,vt)) in arcs:
        if u == v and u == depart :
            arcs_transforme.add(((u,tu),0,(v,vt)))
        else:
            arcs_transforme.add(((u,tu),(vt-tu),(v,vt)))
    return sommet_transforme,arcs_transforme

# %%
#---------------------------------------------TEST--------------------------------------------- 
G2 = transformation2(Gclassique,'a')
print(G2)
# Out:
# ({('a', 4): 0, ('a', 1): 1, ('b', 3): 2, ('c', 3): 3, ('c', 5): 4, ('g', 8): 5, ('b', 2): 6, ('f', 7): 7, ('b', 5): 8, ('c', 7): 9, ('a', 2): 10, ('c', 6): 11, ('f', 6): 12}, {(('b', 2), 1, ('b', 3)), (('c', 7), 1, ('g', 8)), (('a', 2), 0, ('a', 4)), (('a', 2), 1, ('b', 3)), (('b', 5), 1, ('f', 6)), (('c', 6), 1, ('f', 7)), (('a', 4), 1, ('c', 5)), (('a', 2), 1, ('c', 3)), (('c', 6), 1, ('c', 7)), (('c', 3), 2, ('c', 5)), (('b', 3), 2, ('b', 5)), (('a', 1), 1, ('b', 2)), (('c', 5), 1, ('c', 6)), (('a', 1), 0, ('a', 2)), (('f', 6), 1, ('f', 7))})

# %% [markdown]
# ## DIJKSTRA type 2
# fonction : **dijkstra2(Gclassique, depart, arrivee, t_alpha, t_omega)** <br>

# %%
def dijkstra2(Gclassique, depart, arrivee, t_alpha, t_omega):
    """
    Cette fonction permet de faire l'algo de dijkstra pour le type II
    """
    G = transformation2(Gclassique,depart)
    arrivee = sommetMax(G,arrivee, t_omega) 
    depart = sommetMin(G,depart, t_alpha)

    V,E = G
    
    Degres, Predecesseur = initDijkstra(G, depart) # on initialise les degres et predecesseur 
    
    DejaVu = set()
    NonVisite = V.copy()
    while len(NonVisite)!=0 and (trouveMin(NonVisite,Degres) != arrivee):
        s1,t1 = trouveMin(NonVisite,Degres)
        DejaVu.add(s1)
        NonVisite.pop((s1,t1))
        for ((s,t),time,(s2,t2)) in E : # maj des dist
            if (s,t) == (s1,t1) :
                if Degres[V[(s2,t2)]] > Degres[V[(s1,t1)]] + time : 
                    Degres[V[(s2,t2)]] = Degres[V[(s1,t1)]] + time
                    Predecesseur[V[(s2,t2)]] = (s1,t1)
    s = arrivee
    Sol = [s]
    while s != depart and s!=None :
        s = Predecesseur[V[s]]
        Sol = [s] + Sol
    if s == None:  
        return []
    return Sol

# %%
#---------------------------------------------TEST--------------------------------------------- 
print(dijkstra2(Gclassique,'a','f',-math.inf,math.inf))
#---------------------------------------------TEST--------------------------------------------- 
print(dijkstra2(Gclassique,'a','c',-math.inf,math.inf))
#---------------------------------------------TEST--------------------------------------------- 
print(dijkstra2(Gclassique,'a','b',-math.inf,math.inf))
# Out:
# [('a', 1), ('a', 2), ('a', 4), ('c', 5), ('c', 6), ('f', 7)]
# [('a', 1), ('a', 2), ('a', 4), ('c', 5), ('c', 6), ('c', 7)]
# [('a', 1), ('a', 2), ('b', 3), ('b', 5)]

# %% [markdown]
# # <font color='red'> Chemin le plus rapide, Type III  </font>
# Pour résoudre le probléme du **chemin le plus rapide, de type 3,** on va procéder de la maniere suivante.<br>
# Tout d'abord, on va transformer le multigraphe en un graphe classique grace aux fonctions précédentes et de ce nouveau graphe on va modifier la valeurs des arêtes.<br> Chaque arc de (depart,t1) a (depart,t2) et (arrivee,t1) a (arrivee,t2) de valeur x va etre **remplacé** par <font color='red' >la valeur de 0 </font> et le reste des arcs de (u,t1) a (v,t2) sera remplacé par <font color='red' >t2 - t1</font>. <br>
# Enfin, on applique dijkstra entre le min du depart et le max de l'arrivée

# %% [markdown]
# ## Graphe classique en graphe de type 3

# %%
def transformation3(Gclassique,depart,arrivee):
    """
    Cette fonction transforme le graphe classique  pour le type 3
    """
    sommets,arcs = Gclassique
    sommets_transforme,arcs_transforme = sommets,set()
    for ((u,tu),temps,(v,vt)) in arcs:
        if u == v and u == depart :
            arcs_transforme.add(((u,tu),0,(v,vt)))
        elif u == v and u == arrivee :
            arcs_transforme.add(((u,tu),0,(v,vt)))
        elif u == v :
            arcs_transforme.add(((u,tu),(vt-tu),(v,vt)))
        else:
            arcs_transforme.add(((u,tu),(vt-tu),(v,vt)))
    return sommets_transforme,arcs_transforme

# %%
#---------------------------------------------TEST--------------------------------------------- 
Gtype3 = transformation3(Gclassique,'a','d')
print(Gtype3)
# Out:
# ({('a', 4): 0, ('a', 1): 1, ('b', 3): 2, ('c', 3): 3, ('c', 5): 4, ('g', 8): 5, ('b', 2): 6, ('f', 7): 7, ('b', 5): 8, ('c', 7): 9, ('a', 2): 10, ('c', 6): 11, ('f', 6): 12}, {(('b', 2), 1, ('b', 3)), (('c', 7), 1, ('g', 8)), (('a', 2), 0, ('a', 4)), (('a', 2), 1, ('b', 3)), (('b', 5), 1, ('f', 6)), (('c', 6), 1, ('f', 7)), (('a', 4), 1, ('c', 5)), (('a', 2), 1, ('c', 3)), (('c', 6), 1, ('c', 7)), (('c', 3), 2, ('c', 5)), (('b', 3), 2, ('b', 5)), (('a', 1), 1, ('b', 2)), (('c', 5), 1, ('c', 6)), (('a', 1), 0, ('a', 2)), (('f', 6), 1, ('f', 7))})

# %% [markdown]
# ## DIJKSTRA type 3
# fonction : **dijkstra3(Gclassique, depart, arrivee, t_alpha, t_omega)** <br>
# renvoi : solution

# %%
def dijkstra3(Gclassique, depart, arrivee, t_alpha, t_omega):
    """
    Cette fonction permet de faire l'algo de dijkstra pour le type III
    """
    G = transformation3(Gclassique,depart,arrivee)
    arrivee = sommetMax(G,arrivee, t_omega) 
    depart = sommetMin(G,depart, t_alpha)

    V,E = G
    
    Degres, Predecesseur = initDijkstra(G, depart) # on initialise les degres et predecesseur 
    
    DejaVu = set()
    NonVisite = V.copy()
    while len(NonVisite)!=0 and (trouveMin(NonVisite,Degres) != arrivee):
        s1,t1 = trouveMin(NonVisite,Degres)
        DejaVu.add(s1)
        NonVisite.pop((s1,t1))
        for ((s,t),time,(s2,t2)) in E : # maj des dist
            if (s,t) == (s1,t1) :
                if Degres[V[(s2,t2)]] > Degres[V[(s1,t1)]] + time : 
                    Degres[V[(s2,t2)]] = Degres[V[(s1,t1)]] + time
                    Predecesseur[V[(s2,t2)]] = (s1,t1)
    s = arrivee
    Sol = [s]
    while s != depart and s!=None :
        s = Predecesseur[V[s]]
        Sol = [s] + Sol
    if s == None:  
        return []
    return Sol

# %%
#---------------------------------------------TEST--------------------------------------------- 
print(dijkstra3(Gclassique,'a','b',-math.inf,math.inf))
#---------------------------------------------TEST--------------------------------------------- 
print(dijkstra3(Gclassique,'a','c',-math.inf,math.inf))
#---------------------------------------------TEST--------------------------------------------- 
print(dijkstra3(Gclassique,'a','d',-math.inf,math.inf))
#---------------------------------------------TEST--------------------------------------------- 
print(dijkstra3(Gclassique,'a','k',-math.inf,math.inf))
# Out:
# [('a', 1), ('a', 2), ('b', 3), ('b', 5)]
# [('a', 1), ('a', 2), ('a', 4), ('c', 5), ('c', 6), ('c', 7)]
# []
# []

# %% [markdown]
# # <font color='red'> Le plus court chemin, Type IV  </font>
# Pour résoudre ce type, on va prendre le graphe classique de base et on lui applique directement dijkstra du min{depart} au max{arrivee}.

# %%
def dijkstra4(Gclassique, depart, arrivee, t_alpha, t_omega):
    """
        Cette fonction permet de faire l'algo de dijkstra pour le type IV
    """
    arrivee = sommetMax(Gclassique,arrivee, t_omega) 
    depart = sommetMin(Gclassique,depart, t_alpha)

    V,E = Gclassique
    
    Degres, Predecesseur = initDijkstra(Gclassique, depart) # on initialise les degres et predecesseur 
    
    DejaVu = set()
    NonVisite = V.copy()
    while len(NonVisite)!=0 and (trouveMin(NonVisite,Degres) != arrivee):
        s1,t1 = trouveMin(NonVisite,Degres)
        DejaVu.add(s1)
        NonVisite.pop((s1,t1))
        for ((s,t),time,(s2,t2)) in E : # maj des dist
            if (s,t) == (s1,t1) :
                if Degres[V[(s2,t2)]] > Degres[V[(s1,t1)]] + time : 
                    Degres[V[(s2,t2)]] = Degres[V[(s1,t1)]] + time
                    Predecesseur[V[(s2,t2)]] = (s1,t1)
    s = arrivee
    Sol = [s]
    while s != depart and s!=None :
        s = Predecesseur[V[s]]
        Sol = [s] + Sol
    if s == None:  
        return []
    return Sol

# %%
#---------------------------------------------TEST--------------------------------------------- 
print(dijkstra4(Gclassique,'a','b',-math.inf,math.inf))
#---------------------------------------------TEST--------------------------------------------- 
print(dijkstra4(Gclassique,'a','c',-math.inf,math.inf))
#---------------------------------------------TEST--------------------------------------------- 
print(dijkstra4(Gclassique,'a','i',-math.inf,math.inf))
# print(Gclassique)
# Out:
# [('a', 1), ('a', 2), ('b', 3), ('b', 5)]
# [('a', 1), ('a', 2), ('a', 4), ('c', 5), ('c', 6), ('c', 7)]
# []

# %% [markdown]
# # <font color='red'> Programmation Lineaire, Type IV  </font>
#  On va implanter une méthode de recherche de chemin de Type IV en faisant appel a GUROBI.

# %%
from gurobipy import *

def PL4(Gclassique, departs, arrivees,t_alpha,t_omega):
    
    sommets,arcs = Gclassique
    
    depart = sommetMin(Gclassique,departs,t_alpha) # min des departs
    arivee = sommetMax(Gclassique,arrivees,t_omega) # max des arrives

        
    nbconst = len(sommets) # nombre de contraintes 
    nbvar = len(arcs) # nombre de variable de decision

    lines = range(nbconst)
    columns = range(nbvar)

    V = list(sommets) # liste sommets 
    E = [((s1,t1),(s2,t2)) for ((s1,t1),_,(s2,t2))in arcs] #liste aretes sans temps 

    A = np.zeros((nbconst, nbvar)) # matrice de contraintes , matrice incidente

    for (s1,t1),_,(s2,t2) in arcs: # pour tout les arcs 
        i, j = V.index( (s1,t1)), V.index((s2,t2)) # on prend le sommet de depart et d'arrive 
        k = E.index(((s1,t1), (s2,t2))) # on prend l'index de l'arc 
        A[i, k] = 1 # sommet de depart a 1 
        A[j, k] = -1 # sommet d'arrive a -1

    # Second member vector
    b = np.zeros(nbconst)
    b[V.index(depart)] = 1
    b[V.index(arivee)] = -1

    # Objective coefficients
    c = [time for (_,_),time,(_,_) in arcs] # le cout de l'arc 

    m = Model("pl")

    # Variables declaration (edges)
    x = [m.addVar(vtype=GRB.BINARY, lb=0, name=f"x{i+1}") for i in columns]

    # Model update
    m.update()

    obj = LinExpr()
    obj = 0
    for j in columns:
        obj += c[j] * x[j]

    # Define the objective function
    m.setObjective(obj, GRB.MINIMIZE)

    # Define constraints
    for i in lines:
        m.addConstr(quicksum(A[i][j] * x[j] for j in columns) == b[i], f"Contrainte{i}")

    # Resolve & build the path
    m.optimize()

    var = [depart]

    print("\nSolution optimale:")

    for j in columns:
        # print(f"x{j+1}\t= {int(x[j].x)}")
        if x[j].x == 1:
            var.append(E[j][1])

    print("\nValeur de la fonction objectif :", m.objVal)

    return var

# %%
#---------------------------------------------TEST--------------------------------------------- 
print(sorted(PL4(Gclassique,'a','b',-math.inf,math.inf)))
#---------------------------------------------TEST--------------------------------------------- 
print(sorted(PL4(Gclassique,'a','c',-math.inf,math.inf)))
#---------------------------------------------TEST--------------------------------------------- 
print(sorted(PL4(Gclassique,'a','f',-math.inf,math.inf)))
#---------------------------------------------TEST--------------------------------------------- 
print(sorted(PL4(Gclassique,'a','g',-math.inf,math.inf)))
# print(Gclassique)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2022-02-01
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 13 rows, 15 columns and 30 nonzeros
# Model fingerprint: 0xae1c5040
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 13 rows and 15 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  1.000000000e+00
#
# Solution optimale:
#
# Valeur de la fonction objectif : 1.0
# [('a', 1), ('a', 2), ('b', 3), ('b', 5)]
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 13 rows, 15 columns and 30 nonzeros
# Model fingerprint: 0x0dabe65e
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 11 rows and 13 columns
# Presolve time: 0.01s
# Presolved: 2 rows, 2 columns, 4 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#        0    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  1.000000000e+00
#
# Solution optimale:
#
# Valeur de la fonction objectif : 1.0
# [('a', 1), ('a', 2), ('a', 4), ('c', 5), ('c', 6), ('c', 7)]
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 13 rows, 15 columns and 30 nonzeros
# Model fingerprint: 0x03a1af81
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 10 rows and 10 columns
# Presolve time: 0.01s
# Presolved: 3 rows, 5 columns, 10 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.0000000e+00   0.000000e+00   0.000000e+00      0s
#        0    2.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  2.000000000e+00
#
# Solution optimale:
#
# Valeur de la fonction objectif : 2.0
# [('a', 1), ('a', 2), ('b', 3), ('b', 5), ('f', 6), ('f', 7)]
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 13 rows, 15 columns and 30 nonzeros
# Model fingerprint: 0x04f79c98
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 11 rows and 13 columns
# Presolve time: 0.01s
# Presolved: 2 rows, 2 columns, 4 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.0000000e+00   0.000000e+00   0.000000e+00      0s
#        0    2.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  2.000000000e+00
#
# Solution optimale:
#
# Valeur de la fonction objectif : 2.0
# [('a', 1), ('a', 2), ('a', 4), ('c', 5), ('c', 6), ('c', 7), ('g', 8)]

# %% [markdown]
# # **------------------------------------------------------------------**

# %% [markdown]
# # ------------------ <font color ='red'>**TEST DES ALGORITHMES**</font> ------------------

# %% [markdown]
# # **------------------------------------------------------------------**

# %% [markdown]
# ## Test sur une instance commune

# %%
#-------------------------------------------------- TEST -------------------------------------------------- 
#------------------------------ on test toute les fonctions sur une instance ------------------------------

# >>>>>>>> importer le fichier depuis un fichier texte 
f = 'instancetest.txt'
# f = 'instancetest2.txt'
graphe = ouvrir_fichier(f)

# >>>>>>>> on cree le multigraphe avec le terminal
#graphe = creer_graphe_terminal() 

# >>>>>>>> On transforme le multigraphe en graphe classique 
Gclassique = graphe_classique(graphe)
sommets , arcs = Gclassique
print(f">>>>> Les sommets du graphes classique sont : \n {sommets}")
print("-----     -----     -----     -----     -----     -----     -----    -----     -----     -----     -----    -----")
print(f">>>>> Les arcs du graphe classique sont : \n {arcs}") 

# >>>>>>>> On choisis les de depart et d'arrive 
depart = 'a'
arrivee = 'i'
t_alpha = -math.inf
t_omega = math.inf
print("-----------------------------------------------------------------------------------------------------------------")
print(f"On a choisis comme sommet de depart : {depart} \n et comme sommet d'arrive : {arrivee}")

print("-----------------------------------------------------------------------------------------------------------------") 
# ------------------------------ Chemin d'arrivé au plus tot, Type I ------------------------------
arrive_plus_tot = dijkstra1(Gclassique,depart,arrivee,t_alpha,t_omega)
print(f"Le chemin d'arrivee au plus tot de {depart} vers {arrivee} dans le graphe classique est le suivant : \n {arrive_plus_tot}")

print("-----------------------------------------------------------------------------------------------------------------")
# ------------------------------ Chemin de depart au plus tard, Type II ------------------------------
depart_plus_tard = dijkstra2(Gclassique,depart,arrivee,t_alpha,t_omega)
print(f"Le chemin de depart au plus tard de {depart} vers {arrivee} dans le graphe classique est le suivant: \n{depart_plus_tard}")

print("-----------------------------------------------------------------------------------------------------------------")
# ------------------------------ Chemin le plus rapide , Type III ------------------------------
plus_rapide = dijkstra3(Gclassique,depart,arrivee,t_alpha,t_omega)
print(f"Le chemin le plus rapide de {depart} vers {arrivee} dans le graphe classique est le suivant :\n {plus_rapide}")

print("-----------------------------------------------------------------------------------------------------------------")
# ------------------------------ Chemin le plus court, Type IV ------------------------------
plus_court = dijkstra4(Gclassique,depart,arrivee,t_alpha,t_omega)
print(f"Le chemin le plus court de {depart} vers {arrivee} dans le graphe classique est le suivant : \n{plus_court}")


print("-----------------------------------------------------------------------------------------------------------------") 
# ------------------------------ Chemin le plus court par programmation lineaire, type IV ------------------------------
PL = PL4(Gclassique, depart, arrivee, t_alpha, t_omega)
print(f"Le chemin le plus court par programmation lineaire de {depart} vers {arrivee} dans le graphe classique est le suivant : {sorted(PL)}")
# Out:
# Le nombre de sommets est :  10
# Le nombres d'arc est : 15
# >>>>> Les sommets du graphes classique sont :
#  {('k', 8): 0, ('f', 4): 1, ('a', 2): 2, ('g', 6): 3, ('b', 3): 4, ('l', 10): 5, ('k', 7): 6, ('i', 6): 7, ('c', 6): 8, ('i', 9): 9, ('a', 4): 10, ('a', 1): 11, ('h', 4): 12, ('h', 7): 13, ('a', 10): 14, ('g', 2): 15, ('b', 2): 16, ('l', 9): 17, ('i', 8): 18, ('j', 3): 19, ('f', 5): 20, ('i', 11): 21, ('c', 5): 22, ('a', 3): 23, ('g', 4): 24}
# -----     -----     -----     -----     -----     -----     -----    -----     -----     -----     -----    -----
# >>>>> Les arcs du graphe classique sont :
#  {(('i', 8), 0, ('i', 9)), (('b', 3), 1, ('g', 4)), (('a', 10), 1, ('i', 11)), (('a', 1), 1, ('b', 2)), (('i', 9), 0, ('i', 11)), (('a', 1), 0, ('a', 2)), (('f', 5), 1, ('i', 6)), (('h', 7), 1, ('i', 8)), (('a', 4), 0, ('a', 10)), (('g', 6), 1, ('k', 7)), (('a', 4), 1, ('c', 5)), (('h', 4), 0, ('h', 7)), (('k', 7), 0, ('k', 8)), (('i', 8), 1, ('l', 9)), (('i', 9), 1, ('l', 10)), (('b', 3), 1, ('h', 4)), (('a', 2), 1, ('b', 3)), (('a', 2), 0, ('a', 3)), (('b', 2), 0, ('b', 3)), (('a', 3), 0, ('a', 4)), (('h', 7), 1, ('k', 8)), (('f', 4), 0, ('f', 5)), (('c', 5), 0, ('c', 6)), (('g', 2), 0, ('g', 4)), (('g', 2), 1, ('j', 3)), (('c', 6), 1, ('h', 7)), (('i', 6), 0, ('i', 8)), (('g', 4), 0, ('g', 6)), (('a', 3), 1, ('f', 4)), (('l', 9), 0, ('l', 10))}
# -----------------------------------------------------------------------------------------------------------------
# On a choisis comme sommet de depart : a
#  et comme sommet d'arrive : i
# -----------------------------------------------------------------------------------------------------------------
# Le chemin d'arrivee au plus tot de a vers i dans le graphe classique est le suivant :
#  [('a', 1), ('a', 2), ('a', 3), ('f', 4), ('f', 5), ('i', 6), ('i', 8), ('i', 9), ('i', 11)]
# -----------------------------------------------------------------------------------------------------------------
# Le chemin de depart au plus tard de a vers i dans le graphe classique est le suivant:
# [('a', 1), ('a', 2), ('a', 3), ('a', 4), ('a', 10), ('i', 11)]
# -----------------------------------------------------------------------------------------------------------------
# Le chemin le plus rapide de a vers i dans le graphe classique est le suivant :
#  [('a', 1), ('a', 2), ('a', 3), ('a', 4), ('a', 10), ('i', 11)]
# -----------------------------------------------------------------------------------------------------------------
# Le chemin le plus court de a vers i dans le graphe classique est le suivant :
# [('a', 1), ('a', 2), ('a', 3), ('a', 4), ('a', 10), ('i', 11)]
# -----------------------------------------------------------------------------------------------------------------
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 25 rows, 30 columns and 60 nonzeros
# Model fingerprint: 0x0d6de567
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 22 rows and 24 columns
# Presolve time: 0.01s
# Presolved: 3 rows, 6 columns, 12 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.000000e+00   0.000000e+00      0s
#        1    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  1.000000000e+00
#
# Solution optimale:
#
# Valeur de la fonction objectif : 1.0
# Le chemin le plus court par programmation lineaire de a vers i dans le graphe classique est le suivant : [('a', 1), ('a', 2), ('a', 3), ('a', 4), ('a', 10), ('i', 11)]

# %% [markdown]
# ## Test sur des instances générés aléatoirement

# %% [markdown]
# ### Generation de graphe sans circuit

# %%
def graphe_sans_circuit(n,p=0.5,lambd=1):
    """
    Cette fonction nous permet de créer des graphes sans circuit généres aléatoirement
    """
    sommets = []
    arcs = set()
    # on crée les sommets
    for i in range(n):
        sommets.append(str(i))
    
    # on crée les aretes 
    for i in range(len(sommets)):
        sommetRestants = sommets[(i+1):]
        # on voit que les sommets suivant et jamais ceux d'avant pour eviter d'avoir des circuits 
        for j in sommetRestants:
            tirage = random.random()
            if tirage <= p: # proba d'avoir un arc 
                arcs.add((str(i),j,random.randint(1,np.ceil(n/2)),lambd)) # la valeur de t choisis aléatoirement 
    # pour adapter a nos fonctions qui ont un dico pour les sommets 
    sommet_dico = {}
    for i in range(len(sommets)):
        sommet_dico[sommets[i]] = i
    return sommet_dico,arcs

# %%
G = graphe_sans_circuit(3)
print(G)
# Out:
# ({'0': 0, '1': 1, '2': 2}, {('0', '2', 1, 1)})

# %% [markdown]
# ## Fonction utiles aux tests

# %%
def calcule_qualiter_temps_execution(listeListeGraphe,liste_fonction):
    temps_execution = []
    qualiter = []
    #Parcours les algos
    for i in np.arange(len(liste_fonction)):
        # calcule le temps d’exécution pour un algo en fonction des différents parametres
        resultat = []
        resultat2 = []
        
        #Parcours la liste de graphe chaque élément de cette liste est compose dans notre cas de 10 graphes de parametre n,p
        # On realise cette opération afin de pouvoir faire une moyenne sur les instances afins d’avoir des résultats les plus cohérents 
        for list_graphe in listeListeGraphe:
           
            temps = []
            temps2 = []
           
            # Parcours chaque graphe de parametre n,p de la liste_graphe
            for graphe in list_graphe :
                # Calcule le temps d’exécution pour un graphe pour une fonction
                debut = time.time()
                couverture = liste_fonction[i](graphe,str(0),str(len(graphe)-1),-math.inf,math.inf)
                fin = time.time()
                temps.append((fin - debut))
                temps2.append(len(couverture))
               
            resultat.append(np.mean(temps))
            resultat2.append(np.mean(temps2))
            
        temps_execution.append(resultat)
        qualiter.append(resultat2)
       
    return np.array(temps_execution),np.array(qualiter)
    
def graphique_comparaison(n_p,resultat_temps,P,nom_axeX,nom_axeY,nom_titre):
    
    val = int(len(n_p) / len(P))
    for i in range(1,len(P)+1):
       
        x = n_p[(i-1)*val:i*val,0]
        y = resultat_temps[(i-1)*val:i*val]
        plt.plot(x,y, label= ' p = ' + str(P[i-1]))

    plt.xlabel(nom_axeX)
    plt.ylabel(nom_axeY)
    plt.title(nom_titre)
    plt.legend()
    plt.show()

    coeff_directeur = []
   
    x = np.array(n_p)
    y = np.array(resultat_temps)
    for i in range(0,len(P)):
       
        deltaX = x[(i+1)*val-1] - x[i*val]
        deltaY = y[(i+1)*val-1] - y[i*val]
        coeff_directeur.append(deltaY/deltaX[0])
    return coeff_directeur

def graphique_passage_log(n_p,resultat_temps,P,nom_axeX,nom_axeY,nom_titre):
    x = np.array(n_p)
    y = np.log(np.array(resultat_temps))
    val = int(len(n_p) / len(P))
    graphique_comparaison(x,y,P,nom_axeX,nom_axeY,nom_titre)
    coeff_directeur = []
    
    for i in range(0,len(P)):
        deltaX = x[(i+1)*val-1] - x[i*val]
        deltaY = y[(i+1)*val-1] - y[i*val]
        coeff_directeur.append(deltaY/deltaX[0])
    return coeff_directeur

def graphique_passage_log_log(n_p,resultat_temps,P,nom_axeX,nom_axeY,nom_titre):
    x = np.log(np.array(n_p))
    y = np.log(np.array(resultat_temps))
    val = int(len(n_p) / len(P))
    graphique_comparaison(x,y,P,nom_axeX,nom_axeY,nom_titre)
    coeff_directeur = []
    
    for i in range(0,len(P)):
       
        deltaX = x[(i+1)*val-1] - x[i*val]
        deltaY = y[(i+1)*val-1] - y[i*val]
        coeff_directeur.append(deltaY/deltaX[0])
    return coeff_directeur


def parametre_grille_search(nmin,nmax,pas_n,pmin,pmax,pas_p):
    N = [i for i in np.arange(nmin,nmax,pas_n) ]
    P = [i for i in np.arange(pmin,pmax,pas_p)]
    return np.array([(n,p) for p in P for n in N ]),N,P


def graphe_grille_search(n_p,iters=10):
    listeListeGraphe = []
    for n,p in n_p :
        temps = []
        for _ in np.arange(iters):
            #changer que ici 
            temps.append(graphe_classique(graphe_sans_circuit(int(n),p)))
        listeListeGraphe.append(temps)
    return np.array(listeListeGraphe)

def test_experimentale(n_p,P,iters,liste_fonction,nom_liste_fonction,dico_bool):
    listeListeGraphe = graphe_grille_search(n_p,iters)
    execution,qualiter = calcule_qualiter_temps_execution(listeListeGraphe,liste_fonction)
    nb_couverture = []
    coeff_directeur = []
    coeff_directeur_log = []
    coeff_directeur_log_log = []

    if dico_bool['execution'] :
        #Temps execution
        for i in np.arange(len(execution)):
            coeff_directeur.append((nom_liste_fonction[i],graphique_comparaison(n_p,execution[i],P,'Nombre de sommets','Temps en secondes','Algo ' + nom_liste_fonction[i] ))) 
            coeff_directeur_log.append((nom_liste_fonction[i],graphique_passage_log(n_p,execution[i],P,'Nombre de sommets','Temps en Log secondes','Algo ' + nom_liste_fonction[i] + ' Log')))
            coeff_directeur_log_log.append((nom_liste_fonction[i],graphique_passage_log_log(n_p,execution[i],P,'Nombre de Log sommets','Temps en Log secondes','Algo '+ nom_liste_fonction[i] +' Log-Log')))
        
    dico_resultat = dict()
    dico_resultat['coeff_directeur'] = coeff_directeur
    dico_resultat['coeff_directeur_log'] = coeff_directeur_log
    dico_resultat['coeff_directeur_log_log'] = coeff_directeur_log_log
    dico_resultat['execution'] = execution
    return dico_resultat

# %% [markdown]
# ## TESTS

# %%
n_p,_,P = parametre_grille_search(20,50,2,0.40,0.81,0.1) #nmin,nmax,pas_n,pmin,pmax,pas_p
liste_fonction = [dijkstra1,dijkstra2,dijkstra3,dijkstra4]
nom_liste_fonction = ['type I','type II','type III','type IV']
dico_bool = {'execution':True, 'nb_couverture': False, 'rapport': False}
dico_resultat = test_experimentale(n_p,P,10,liste_fonction,nom_liste_fonction,dico_bool)
print(dico_resultat)
# Out:
# {'coeff_directeur': [('type I', [0.004746760640825544, 0.007436215877532959, 0.009206701176507131, 0.014386133636747086, 0.014211311510631016]), ('type II', [0.006197275434221541, 0.005394344670431955, 0.011231918845857893, 0.013185001271111624, 0.011177298852375577]), ('type III', [0.003102540118353707, 0.0015647147383008684, 0.006604203156062535, 0.008098573344094412, 0.0036993469510759624]), ('type IV', [0.003713463885443551, 0.002732248817171369, 0.009580961295536585, 0.009257344688688007, 0.005192436490740095])], 'coeff_directeur_log': [('type I', [0.10963407089298768, 0.14281137384913772, 0.10961440763403478, 0.11712522001905115, 0.1301248063324493]), ('type II', [0.1083421418035974, 0.12816500644675385, 0.13120075617791288, 0.12706462241379607, 0.12080456170134206]), ('type III', [0.10543339076158213, 0.10300480837658034, 0.12195496771152925, 0.121628310755914, 0.09503088944559131]), ('type IV', [0.11118358116801941, 0.11284314723103361, 0.13120497293869376, 0.10619369724759269, 0.10049841586507686])], 'coeff_directeur_log_log': [('type I', [3.5064118843146477, 4.5675171450004735, 3.505782996923026, 3.7460003088696494, 4.161764346173027]), ('type II', [3.4650922883548154, 4.099084327506307, 4.196176306746328, 4.063890891569413, 3.8636762037457215]), ('type III', [3.3720620912713715, 3.294389064378851, 3.900469485916596, 3.890022060021216, 3.0393602774657684]), ('type IV', [3.5559696650208137, 3.6090473453327876, 4.196311170844642, 3.396378872328157, 3.214227446576012])], 'execution': array([[0.00647182, 0.00897601, 0.00847731, 0.01194894, 0.02099512,
#         0.02553592, 0.02582874, 0.04888263, 0.04073281, 0.06991615,
#         0.07540307, 0.11274447, 0.16750963, 0.1282223 , 0.13938112,
#         0.0038898 , 0.01006813, 0.01306977, 0.01632826, 0.01935251,
#         0.0237314 , 0.03108509, 0.03889596, 0.05495312, 0.05432539,
#         0.09414816, 0.08041546, 0.2008225 , 0.15783703, 0.21210384,
#         0.01255984, 0.0160001 , 0.03554175, 0.02278941, 0.00870976,
#         0.03505688, 0.05732479, 0.08200269, 0.08462801, 0.15367308,
#         0.09943409, 0.15132279, 0.13215241, 0.23129003, 0.27034748,
#         0.01575782, 0.0188565 , 0.02867787, 0.03622432, 0.04188213,
#         0.04898551, 0.05676913, 0.07848971, 0.09143348, 0.13912272,
#         0.14886489, 0.13527617, 0.34830351, 0.30615478, 0.41856956,
#         0.01068945, 0.01420074, 0.01811295, 0.04933257, 0.04791982,
#         0.03057134, 0.10015707, 0.10350857, 0.09755368, 0.06535487,
#         0.17720695, 0.1455905 , 0.2656193 , 0.4311594 , 0.40860617],
#        [0.00877647, 0.01346397, 0.01655574, 0.01501105, 0.01180203,
#         0.02246408, 0.02497599, 0.0482816 , 0.06649165, 0.05953557,
#         0.10473437, 0.09155664, 0.17655799, 0.18537576, 0.18230019,
#         0.00429289, 0.00757837, 0.01067352, 0.03077748, 0.03283815,
#         0.03520546, 0.05002029, 0.05347857, 0.09777019, 0.10309126,
#         0.10753579, 0.17736049, 0.23039384, 0.20331347, 0.15533454,
#         0.00819116, 0.01176777, 0.02373602, 0.0316169 , 0.03520522,
#         0.04524832, 0.06093705, 0.08453798, 0.10172884, 0.15086067,
#         0.14394104, 0.21838911, 0.22857602, 0.3325321 , 0.32268488,
#         0.01083076, 0.01526949, 0.025001  , 0.03027954, 0.02693033,
#         0.04647954, 0.06542845, 0.07543542, 0.13929105, 0.20116503,
#         0.19273357, 0.25612032, 0.3176218 , 0.37849841, 0.3800108 ,
#         0.0110024 , 0.01348622, 0.03105602, 0.05829887, 0.04648139,
#         0.06590304, 0.08607082, 0.13377237, 0.13764117, 0.16587074,
#         0.17333457, 0.29187353, 0.31567781, 0.33808231, 0.32396677],
#        [0.00478714, 0.00651426, 0.00797863, 0.01007304, 0.00988958,
#         0.01983364, 0.01775239, 0.03694267, 0.03778358, 0.04661653,
#         0.07420938, 0.07405932, 0.10432265, 0.1225045 , 0.09165826,
#         0.00259426, 0.0063843 , 0.00827293, 0.01459355, 0.01531262,
#         0.02065029, 0.02214897, 0.02955036, 0.0470762 , 0.04140279,
#         0.06820269, 0.07546346, 0.13512859, 0.09384897, 0.04640627,
#         0.00628779, 0.00808935, 0.02256637, 0.02287555, 0.00969889,
#         0.03041799, 0.03536108, 0.04952323, 0.06093094, 0.15660448,
#         0.0616905 , 0.18972728, 0.13080823, 0.17482145, 0.19120548,
#         0.00778384, 0.00857725, 0.01615689, 0.0221658 , 0.01465046,
#         0.02423105, 0.03820503, 0.03719995, 0.06113708, 0.10640025,
#         0.0824959 , 0.06757469, 0.22764204, 0.22627585, 0.2345439 ,
#         0.00778303, 0.00750089, 0.01368189, 0.03057325, 0.03032348,
#         0.01769023, 0.05650172, 0.04151819, 0.05764492, 0.02330418,
#         0.06723919, 0.08994725, 0.17568455, 0.31315391, 0.11136475],
#        [0.00483804, 0.00798156, 0.01120543, 0.01456094, 0.01296885,
#         0.02392976, 0.02622919, 0.05346558, 0.05924337, 0.07560172,
#         0.11813881, 0.1088835 , 0.13417127, 0.14742119, 0.10881503,
#         0.00339088, 0.00738027, 0.0092752 , 0.01676018, 0.0167547 ,
#         0.03420739, 0.03320775, 0.03122168, 0.05067747, 0.04596024,
#         0.07414382, 0.10167031, 0.16598094, 0.12678885, 0.07989385,
#         0.00698631, 0.01086991, 0.02712579, 0.03415425, 0.02413824,
#         0.04049115, 0.0474664 , 0.05289865, 0.08385329, 0.1994854 ,
#         0.07763216, 0.1617425 , 0.15545232, 0.22417493, 0.27525322,
#         0.01396675, 0.01515682, 0.03695581, 0.04099386, 0.03161128,
#         0.03536913, 0.05153964, 0.06013448, 0.0812912 , 0.13159647,
#         0.12088833, 0.12890592, 0.24117682, 0.23584189, 0.2731724 ,
#         0.00927472, 0.01172295, 0.02543185, 0.03551753, 0.03991261,
#         0.02841992, 0.07721894, 0.05886219, 0.067975  , 0.05465415,
#         0.09715996, 0.11047487, 0.17423711, 0.25987272, 0.15466294]])}

# %%
n_p,_,P = parametre_grille_search(20,80,2,0.40,0.61,0.1) #nmin,nmax,pas_n,pmin,pmax,pas_p
liste_fonction = [dijkstra1]
nom_liste_fonction = ['type I']
dico_bool = {'execution':True, 'nb_couverture': False, 'rapport': False}
dico_resultat = test_experimentale(n_p,P,2,liste_fonction,nom_liste_fonction,dico_bool)
print(dico_resultat)
# Out:
# {'coeff_directeur': [('type I', [0.016663230698684167, 0.035809442914765455, 0.014449635456348288])], 'coeff_directeur_log': [('type I', [0.09702166433293204, 0.10090055981910592, 0.1089166961784157])], 'coeff_directeur_log_log': [('type I', [4.134719674887291, 4.30002446113049, 4.641643798927887])], 'execution': array([[3.49032879e-03, 1.99484825e-03, 6.98125362e-03, 1.89499855e-02,
#         1.34633780e-02, 5.23601770e-02, 1.14692450e-02, 1.79685354e-02,
#         3.39140892e-02, 1.04698420e-01, 4.34054136e-02, 1.00819945e-01,
#         8.17828178e-02, 2.11686969e-01, 2.37863660e-01, 1.89493537e-01,
#         2.43349671e-01, 4.21396494e-01, 2.71168590e-01, 5.53968549e-01,
#         5.82458377e-01, 4.83209133e-01, 6.90028310e-01, 8.70120049e-01,
#         7.14608550e-01, 1.16456103e+00, 1.08654547e+00, 1.03694713e+00,
#         1.70841491e+00, 9.69957709e-01, 5.98526001e-03, 5.98275661e-03,
#         1.79296732e-02, 1.39827728e-02, 1.94486380e-02, 1.34638548e-02,
#         6.08406067e-02, 7.77901411e-02, 1.06714725e-01, 6.63201809e-02,
#         1.04699850e-01, 3.38566184e-01, 3.28614593e-01, 7.42985010e-02,
#         8.97368193e-02, 2.66807675e-01, 1.90993547e-01, 5.20194650e-01,
#         1.88994527e-01, 3.35125327e-01, 5.61801791e-01, 8.44598889e-01,
#         8.72101426e-01, 1.30792034e+00, 1.36766243e+00, 2.91719913e-01,
#         1.53882289e+00, 1.75029027e+00, 2.10300529e+00, 2.08293295e+00,
#         1.51550770e-03, 1.04495287e-02, 2.04446316e-02, 3.79215479e-02,
#         2.24419832e-02, 3.59022617e-02, 2.59290934e-02, 4.98795509e-03,
#         7.62975216e-02, 1.19133234e-01, 5.03650904e-02, 2.01436877e-01,
#         7.52985477e-02, 3.70036364e-01, 2.57307291e-01, 2.31879950e-01,
#         4.08075094e-01, 2.58573174e-01, 1.56632304e-01, 4.37825561e-01,
#         2.37363935e-01, 8.02829862e-01, 8.21096063e-01, 4.47799683e-01,
#         1.68746591e+00, 3.07819963e-01, 1.43008029e+00, 2.47111881e+00,
#         1.78927386e+00, 8.39594364e-01]])}

# %% [markdown]
# ## test pl

# %%
n_p,_,P = parametre_grille_search(10,50,2,0.40,0.61,0.1) #nmin,nmax,pas_n,pmin,pmax,pas_p
liste_fonction = [PL4,dijkstra4]
nom_liste_fonction = ['PL4','type IV']
dico_bool = {'execution':True, 'nb_couverture': False, 'rapport': False}
dico_resultat = test_experimentale(n_p,P,10,liste_fonction,nom_liste_fonction,dico_bool)
print(dico_resultat)
# Out:
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 18 rows, 19 columns and 38 nonzeros
# Model fingerprint: 0x69dcba91
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.01s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 24 rows, 28 columns and 56 nonzeros
# Model fingerprint: 0x065e4889
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.01s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 28 rows, 36 columns and 72 nonzeros
# Model fingerprint: 0x9884cdd2
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 12 rows and 25 columns
# Presolve time: 0.01s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 21 rows, 25 columns and 50 nonzeros
# Model fingerprint: 0x5b9c692f
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 10 rows and 19 columns
# Presolve time: 0.01s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 28 rows, 36 columns and 72 nonzeros
# Model fingerprint: 0x04aca29d
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 10 rows and 19 columns
# Presolve time: 0.01s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 27 rows, 35 columns and 70 nonzeros
# Model fingerprint: 0xb65a3f3b
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 27 rows and 35 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 31 rows, 42 columns and 84 nonzeros
# Model fingerprint: 0x8092df78
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.01s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 27 rows, 35 columns and 70 nonzeros
# Model fingerprint: 0x873cdfa9
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 27 rows and 35 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 30 rows, 39 columns and 78 nonzeros
# Model fingerprint: 0xef664eaa
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 14 rows and 27 columns
# Presolve time: 0.01s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 34 rows, 48 columns and 96 nonzeros
# Model fingerprint: 0x6975af23
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 15 rows and 31 columns
# Presolve time: 0.01s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 43 rows, 59 columns and 118 nonzeros
# Model fingerprint: 0xe566897e
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 10 rows and 20 columns
# Presolve time: 0.01s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 39 rows, 53 columns and 106 nonzeros
# Model fingerprint: 0xc5ff6858
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 39 rows and 53 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 34 rows, 46 columns and 92 nonzeros
# Model fingerprint: 0xb7466263
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 9 rows and 19 columns
# Presolve time: 0.01s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 39 rows, 56 columns and 112 nonzeros
# Model fingerprint: 0x413a140a
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 39 rows and 56 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 45 rows, 68 columns and 136 nonzeros
# Model fingerprint: 0xe3828535
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 45 rows and 68 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 41 rows, 58 columns and 116 nonzeros
# Model fingerprint: 0x57cf9c04
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 41 rows and 58 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 37 rows, 50 columns and 100 nonzeros
# Model fingerprint: 0x0c2905d9
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 37 rows and 50 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 44 rows, 64 columns and 128 nonzeros
# Model fingerprint: 0xb90e9974
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 44 rows and 64 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 33 rows, 41 columns and 82 nonzeros
# Model fingerprint: 0xb5ea0d69
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 17 rows and 31 columns
# Presolve time: 0.01s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 35 rows, 46 columns and 92 nonzeros
# Model fingerprint: 0xd7f922b3
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 20 rows and 36 columns
# Presolve time: 0.01s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 55 rows, 82 columns and 164 nonzeros
# Model fingerprint: 0xe3cdcaac
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 55 rows and 82 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 55 rows, 75 columns and 150 nonzeros
# Model fingerprint: 0x6a5fa38f
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 55 rows and 75 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 44 rows, 61 columns and 122 nonzeros
# Model fingerprint: 0xb3abc3f9
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 44 rows and 61 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 56 rows, 82 columns and 164 nonzeros
# Model fingerprint: 0xa5d9fb1c
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 56 rows and 82 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 47 rows, 67 columns and 134 nonzeros
# Model fingerprint: 0x685da565
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 47 rows and 67 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 55 rows, 80 columns and 160 nonzeros
# Model fingerprint: 0xa54e0e31
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 16 rows and 34 columns
# Presolve time: 0.01s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 55 rows, 73 columns and 146 nonzeros
# Model fingerprint: 0x32984c56
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 22 rows and 40 columns
# Presolve time: 0.01s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 56 rows, 79 columns and 158 nonzeros
# Model fingerprint: 0x6531c8a9
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 18 rows and 40 columns
# Presolve time: 0.01s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 54 rows, 76 columns and 152 nonzeros
# Model fingerprint: 0xe793bad0
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 19 rows and 44 columns
# Presolve time: 0.01s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 52 rows, 73 columns and 146 nonzeros
# Model fingerprint: 0x7b91424f
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 17 rows and 37 columns
# Presolve time: 0.01s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 57 rows, 83 columns and 166 nonzeros
# Model fingerprint: 0xa9ffff2b
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 57 rows and 83 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 72 rows, 105 columns and 210 nonzeros
# Model fingerprint: 0x429e302d
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 72 rows and 105 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 71 rows, 107 columns and 214 nonzeros
# Model fingerprint: 0x21dbf5e5
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 27 rows and 58 columns
# Presolve time: 0.01s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 58 rows, 81 columns and 162 nonzeros
# Model fingerprint: 0x87b063c9
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 21 rows and 46 columns
# Presolve time: 0.01s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 63 rows, 89 columns and 178 nonzeros
# Model fingerprint: 0xd3d50f1e
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 63 rows and 89 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 65 rows, 90 columns and 180 nonzeros
# Model fingerprint: 0xde2c462e
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 65 rows and 90 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 65 rows, 94 columns and 188 nonzeros
# Model fingerprint: 0x2abb326c
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 65 rows and 94 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 65 rows, 94 columns and 188 nonzeros
# Model fingerprint: 0xd6fe7380
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 17 rows and 37 columns
# Presolve time: 0.02s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 59 rows, 87 columns and 174 nonzeros
# Model fingerprint: 0xb142a117
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 31 rows and 56 columns
# Presolve time: 0.01s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 76 rows, 108 columns and 216 nonzeros
# Model fingerprint: 0x43aa9d44
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 25 rows and 54 columns
# Presolve time: 0.01s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 95 rows, 144 columns and 288 nonzeros
# Model fingerprint: 0xd41b8f33
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 83 rows and 125 columns
# Presolve time: 0.01s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 93 rows, 141 columns and 282 nonzeros
# Model fingerprint: 0xd9f8725b
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 78 rows and 117 columns
# Presolve time: 0.01s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 111 rows, 173 columns and 346 nonzeros
# Model fingerprint: 0xfc452a9b
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 30 rows and 69 columns
# Presolve time: 0.01s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 88 rows, 130 columns and 260 nonzeros
# Model fingerprint: 0x2191160a
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 24 rows and 54 columns
# Presolve time: 0.01s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 87 rows, 130 columns and 260 nonzeros
# Model fingerprint: 0x67dbe3ec
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 21 rows and 47 columns
# Presolve time: 0.01s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 87 rows, 126 columns and 252 nonzeros
# Model fingerprint: 0x76140a10
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 31 rows and 64 columns
# Presolve time: 0.01s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 76 rows, 114 columns and 228 nonzeros
# Model fingerprint: 0x5609cab7
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 27 rows and 59 columns
# Presolve time: 0.01s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 85 rows, 123 columns and 246 nonzeros
# Model fingerprint: 0xc9acd2eb
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 36 rows and 76 columns
# Presolve time: 0.01s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 95 rows, 144 columns and 288 nonzeros
# Model fingerprint: 0x96f225af
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 95 rows and 144 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 83 rows, 118 columns and 236 nonzeros
# Model fingerprint: 0x9a1dc2ae
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 24 rows and 54 columns
# Presolve time: 0.01s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 115 rows, 172 columns and 344 nonzeros
# Model fingerprint: 0x13f038cb
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 115 rows and 172 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 112 rows, 172 columns and 344 nonzeros
# Model fingerprint: 0xc212f2fd
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 112 rows and 172 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 102 rows, 152 columns and 304 nonzeros
# Model fingerprint: 0xd36f32aa
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 91 rows and 139 columns
# Presolve time: 0.01s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 113 rows, 180 columns and 360 nonzeros
# Model fingerprint: 0x7b7b6c1b
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 25 rows and 60 columns
# Presolve time: 0.01s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 106 rows, 164 columns and 328 nonzeros
# Model fingerprint: 0xbf1ff59c
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 31 rows and 78 columns
# Presolve time: 0.01s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 99 rows, 152 columns and 304 nonzeros
# Model fingerprint: 0xa60130e5
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 99 rows and 152 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 120 rows, 189 columns and 378 nonzeros
# Model fingerprint: 0x8d09c3c4
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 31 rows and 73 columns
# Presolve time: 0.01s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 107 rows, 166 columns and 332 nonzeros
# Model fingerprint: 0x9e165a93
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 27 rows and 65 columns
# Presolve time: 0.01s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 110 rows, 164 columns and 328 nonzeros
# Model fingerprint: 0x623b8efb
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 29 rows and 64 columns
# Presolve time: 0.01s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 110 rows, 167 columns and 334 nonzeros
# Model fingerprint: 0x4171641f
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 33 rows and 74 columns
# Presolve time: 0.01s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 113 rows, 165 columns and 330 nonzeros
# Model fingerprint: 0x5ecba3cb
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 40 rows and 87 columns
# Presolve time: 0.01s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 117 rows, 180 columns and 360 nonzeros
# Model fingerprint: 0xe2d1b405
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 117 rows and 180 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 144 rows, 222 columns and 444 nonzeros
# Model fingerprint: 0x96ff1863
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 123 rows and 181 columns
# Presolve time: 0.01s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 134 rows, 209 columns and 418 nonzeros
# Model fingerprint: 0x246cbb5c
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 134 rows and 209 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 120 rows, 177 columns and 354 nonzeros
# Model fingerprint: 0x12aa6b7e
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 34 rows and 77 columns
# Presolve time: 0.01s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 145 rows, 228 columns and 456 nonzeros
# Model fingerprint: 0x993390a5
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 34 rows and 82 columns
# Presolve time: 0.01s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 130 rows, 206 columns and 412 nonzeros
# Model fingerprint: 0xe5e14b84
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 34 rows and 84 columns
# Presolve time: 0.01s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 134 rows, 206 columns and 412 nonzeros
# Model fingerprint: 0x7c6a02fd
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 39 rows and 83 columns
# Presolve time: 0.01s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 114 rows, 179 columns and 358 nonzeros
# Model fingerprint: 0xaba6e879
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 100 rows and 155 columns
# Presolve time: 0.01s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 124 rows, 190 columns and 380 nonzeros
# Model fingerprint: 0x21ecd3a2
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 34 rows and 79 columns
# Presolve time: 0.01s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 146 rows, 220 columns and 440 nonzeros
# Model fingerprint: 0xc7faafa8
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 36 rows and 79 columns
# Presolve time: 0.01s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 159 rows, 248 columns and 496 nonzeros
# Model fingerprint: 0xacc2578b
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 136 rows and 202 columns
# Presolve time: 0.01s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 169 rows, 255 columns and 510 nonzeros
# Model fingerprint: 0x9b0ac231
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 169 rows and 255 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 170 rows, 261 columns and 522 nonzeros
# Model fingerprint: 0x5aa177b8
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 170 rows and 261 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 166 rows, 261 columns and 522 nonzeros
# Model fingerprint: 0x93129354
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 166 rows and 261 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 145 rows, 222 columns and 444 nonzeros
# Model fingerprint: 0x58a3877e
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 132 rows and 189 columns
# Presolve time: 0.01s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 156 rows, 235 columns and 470 nonzeros
# Model fingerprint: 0xc2b245f6
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 156 rows and 235 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 151 rows, 229 columns and 458 nonzeros
# Model fingerprint: 0x21a37128
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 151 rows and 229 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 152 rows, 242 columns and 484 nonzeros
# Model fingerprint: 0x5689914c
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 152 rows and 242 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 159 rows, 245 columns and 490 nonzeros
# Model fingerprint: 0x603a091c
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 159 rows and 245 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 196 rows, 310 columns and 620 nonzeros
# Model fingerprint: 0x8a9e8e68
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 196 rows and 310 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 177 rows, 278 columns and 556 nonzeros
# Model fingerprint: 0x2830b5f1
# ...
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 735 rows, 1306 columns and 2612 nonzeros
# Model fingerprint: 0x2b4db63d
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 735 rows and 1306 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 746 rows, 1323 columns and 2646 nonzeros
# Model fingerprint: 0x82e11f2b
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 746 rows and 1323 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 707 rows, 1248 columns and 2496 nonzeros
# Model fingerprint: 0xc3e2abfc
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 703 rows and 1245 columns
# Presolve time: 0.01s
# Presolved: 4 rows, 3 columns, 6 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#        0    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 751 rows, 1336 columns and 2672 nonzeros
# Model fingerprint: 0x01408102
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 748 rows and 1334 columns
# Presolve time: 0.01s
# Presolved: 3 rows, 2 columns, 4 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#        0    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 751 rows, 1317 columns and 2634 nonzeros
# Model fingerprint: 0x19ff2bb7
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 590 rows and 944 columns
# Presolve time: 0.01s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 739 rows, 1319 columns and 2638 nonzeros
# Model fingerprint: 0x62fc55f2
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 575 rows and 932 columns
# Presolve time: 0.01s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 727 rows, 1259 columns and 2518 nonzeros
# Model fingerprint: 0x4ae899cc
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 727 rows and 1259 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 734 rows, 1295 columns and 2590 nonzeros
# Model fingerprint: 0x21431008
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 734 rows and 1295 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 741 rows, 1330 columns and 2660 nonzeros
# Model fingerprint: 0xd9fdc629
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 587 rows and 947 columns
# Presolve time: 0.01s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 743 rows, 1315 columns and 2630 nonzeros
# Model fingerprint: 0x9aaa28bf
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 601 rows and 935 columns
# Presolve time: 0.01s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 827 rows, 1461 columns and 2922 nonzeros
# Model fingerprint: 0x0eb6430e
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 827 rows and 1461 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 804 rows, 1437 columns and 2874 nonzeros
# Model fingerprint: 0xd80fce21
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 804 rows and 1437 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 805 rows, 1426 columns and 2852 nonzeros
# Model fingerprint: 0x9f088767
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 805 rows and 1426 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 796 rows, 1445 columns and 2890 nonzeros
# Model fingerprint: 0xb9dcd9af
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 796 rows and 1445 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 797 rows, 1420 columns and 2840 nonzeros
# Model fingerprint: 0x3bf1a6f5
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 794 rows and 1418 columns
# Presolve time: 0.01s
# Presolved: 3 rows, 2 columns, 4 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#        0    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 812 rows, 1419 columns and 2838 nonzeros
# Model fingerprint: 0xf4334d2f
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 675 rows and 1086 columns
# Presolve time: 0.01s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 794 rows, 1427 columns and 2854 nonzeros
# Model fingerprint: 0xd9a1a64e
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 791 rows and 1425 columns
# Presolve time: 0.02s
# Presolved: 3 rows, 2 columns, 4 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#        0    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.00 work units)
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 813 rows, 1447 columns and 2894 nonzeros
# Model fingerprint: 0x8c71c41c
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 634 rows and 920 columns
# Presolve time: 0.01s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Infeasible model
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 799 rows, 1399 columns and 2798 nonzeros
# Model fingerprint: 0xd08e718e
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 799 rows and 1399 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.5.0 build v9.5.0rc5 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 821 rows, 1457 columns and 2914 nonzeros
# Model fingerprint: 0x0ff709de
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 821 rows and 1457 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  1.000000000e+00
# {'coeff_directeur': [('type IV', [0.0036588442953009353, 0.0035716841095372255, 0.003853691251654374]), ('PL4', [1.1972397001166093, 1.7618422131789357, 2.2348897657896347])], 'coeff_directeur_log': [('type IV', [0.15415055207642658, 0.1607211903069045, 0.15548230244655736]), ('PL4', [0.15750134105458766, 0.16164612612858562, 0.1625824718687249])], 'coeff_directeur_log_log': [('type IV', [3.734324580037788, 3.8934994614773597, 3.7665864699542655]), ('PL4', [3.8154980398477982, 3.915906196499293, 3.9385893388281135])], 'execution': array([[3.98468971e-04, 4.99057770e-04, 9.02342796e-04, 1.29661560e-03,
#         3.19151878e-03, 4.98657227e-03, 8.07371140e-03, 6.88226223e-03,
#         9.65394974e-03, 1.87544346e-02, 2.00458765e-02, 2.39367008e-02,
#         3.36147785e-02, 4.25812960e-02, 5.30580997e-02, 8.08884621e-02,
#         4.52740908e-02, 1.31020164e-01, 1.70396852e-01, 1.39434552e-01,
#         3.02839279e-04, 7.01451302e-04, 1.19364262e-03, 2.39336491e-03,
#         3.29494476e-03, 4.78668213e-03, 8.87739658e-03, 1.33597612e-02,
#         1.74578667e-02, 2.03454733e-02, 2.94169188e-02, 5.09197235e-02,
#         3.83923769e-02, 4.41817522e-02, 7.28163719e-02, 7.40024328e-02,
#         9.53284979e-02, 7.75927544e-02, 1.82241058e-01, 1.36026835e-01,
#         3.98921967e-04, 1.19826794e-03, 1.79500580e-03, 2.19433308e-03,
#         5.48501015e-03, 5.28163910e-03, 1.37630939e-02, 2.54366398e-02,
#         2.69283772e-02, 2.55312920e-02, 1.84497833e-02, 4.56030607e-02,
#         7.66900301e-02, 3.34106445e-02, 1.00036716e-01, 1.13695312e-01,
#         1.80675435e-01, 1.79713988e-01, 1.80689478e-01, 1.46839190e-01],
#        [1.14758325e-01, 2.17705941e-01, 3.57128954e-01, 5.47919011e-01,
#         9.57956386e-01, 1.44832487e+00, 1.92959983e+00, 2.98022881e+00,
#         4.31481252e+00, 5.59303534e+00, 7.54503713e+00, 9.26569519e+00,
#         1.16105520e+01, 1.55496820e+01, 2.00525466e+01, 2.26545552e+01,
#         3.22247062e+01, 3.53319134e+01, 4.04021260e+01, 4.56098669e+01,
#         1.44214296e-01, 2.52006459e-01, 4.99892354e-01, 8.11566567e-01,
#         1.30944004e+00, 1.97850146e+00, 2.75621977e+00, 4.05632489e+00,
#         5.77619693e+00, 7.60505066e+00, 9.83704872e+00, 1.24821668e+01,
#         1.64317626e+01, 2.05629953e+01, 2.58688539e+01, 3.15101216e+01,
#         3.74901548e+01, 4.56914426e+01, 5.41850165e+01, 6.70942184e+01,
#         1.76527357e-01, 3.39136267e-01, 6.03206706e-01, 1.07733288e+00,
#         1.69452932e+00, 2.61559157e+00, 3.83249996e+00, 5.44554074e+00,
#         7.42674077e+00, 1.00677449e+01, 1.27015687e+01, 1.72041035e+01,
#         2.15356124e+01, 2.77027430e+01, 3.54390837e+01, 4.08868631e+01,
#         5.12277754e+01, 6.21481026e+01, 7.08038127e+01, 8.51023385e+01]])}
